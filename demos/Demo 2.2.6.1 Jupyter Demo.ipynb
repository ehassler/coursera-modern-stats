# %% [markdown]
# # Jupyter Lab Demo
#
# This is a Markdown cell and lets us mix Markdown and Latex!
#
# Recall the model $\beta_0 + \beta_1 \text{Speed} + \epsilon = \text{Stopping Distance}$.

# %%
fit <- lm(
	dist ~ speed, 
	data = cars
)
plot(cars)
abline(fit)
# Out:
# plot without title
